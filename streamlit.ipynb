# %% [markdown]
# ## Streamlit

# %% [markdown]
# #### I. Lý thuyết về Streamlit
# 1. Streamlit là gì?
# Streamlit là một thư viện Python mã nguồn mở, cho phép xây dựng giao diện Web tương
# tác nhanh chóng dành cho các dự án Machine Learning và Data Science.
#
# 2. Cài đặt
#
#     > pip install streamlit
#
# 3. Cách chạy một ứng dụng Streamlit
#
#     > streamlit run app.py

# %%
import streamlit as st
st.title("Tiêu đề")
st.write("Đây là ứng dụng Streamlit đầu tiên của tôi")
# Out:
# 2026-05-22 01:47:52.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:47:52.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:47:52.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:47:52.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:47:52.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:47:52.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# 5. Kết hợp Seaborn để vẽ biểu đồ
#
# Seabon là thư viện trực quan hóa dữ liệu dựa trên Matplotlib, cung cấp giao diện cấp cao để tạo các biểu đồ thống kê và thông tin. Nó giúp dễ dàng tạo ra các biểu đồ đẹp mắt và có ý nghĩa từ dữ liệu.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import streamlit as st

# df là DataFrame chứa dữ liệu về hóa đơn và tiền tip từ bộ dữ liệu "tips" của Seaborn
df = sns.load_dataset("tips")

# fig và ax là đối tượng của Matplotlib để tạo biểu đồ
# sns.scatterplot tạo biểu đồ scatter plot với dữ liệu từ DataFrame df, sử dụng cột "total_bill" làm trục x và cột "tip" làm trục y
fig, ax = plt.subplots()
sns.scatterplot(data=df, x="total_bill", y="tip", ax=ax)
# st.pyplot(fig) hiển thị biểu đồ đã tạo trên ứng dụng Streamlit
st.pyplot(fig)
# Out:
# 2026-05-22 01:51:40.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:51:40.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:51:40.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-22 01:51:40.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
